# %%
datadir = '/storage/groups/ml01/datasets/projects/20210318_retinal_data_integration_ignacio.ibarra_malte.luecken'

# %%
import scanpy as sc
import os
sc.pl.set_rcParams_defaults()

# %%
for f in os.listdir(os.path.join(datadir, 'Chen_a')):
    path_old = os.path.join(datadir, 'Chen_a', f)
    path_new = os.path.join(datadir, 'Chen_a_fix5', f)
    if os.path.exists(path_new):
        print(path_old)
        print(path_new)
        ad_old = sc.read_h5ad(path_old)
        ad_new = sc.read_h5ad(path_new)
        
        for ad, label in zip([ad_old, ad_new], ['old', 'new']):
            print(ad.shape)
            sc.pp.neighbors(ad)
            sc.tl.umap(ad)
            sc.pl.umap(ad, color='scpred_prediction', title=label + ', ' + f)
        print('')
# Out:
# /storage/groups/ml01/datasets/projects/20210318_retinal_data_integration_ignacio.ibarra_malte.luecken/Chen_a/10x_Lobe_D28_13_Nu.h5ad
# /storage/groups/ml01/datasets/projects/20210318_retinal_data_integration_ignacio.ibarra_malte.luecken/Chen_a_fix5/10x_Lobe_D28_13_Nu.h5ad
# (10822, 33538)
# WARNING: You’re trying to run this on 33538 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# ...
