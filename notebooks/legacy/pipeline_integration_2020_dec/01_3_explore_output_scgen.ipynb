# %%
import scanpy as sc

# %%
n_cells_batch = 200
scib_outdir = '/mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/scIB_run/retinal_march_2021_%s_cells' % n_cells_batch
p = '%s/integration/unscaled/hvg/combat.h5ad' % scib_outdir

# %%
ad = sc.read_h5ad(p)

# %%
print(p)
# Out:
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/scIB_run/retinal_march_2021_200_cells/integration/unscaled/hvg/combat.h5ad

# %%
ad.shape
# Out:
# (28391, 2000)

# %%
sc.pp.neighbors(ad)
sc.tl.umap(ad)
# Out:
# WARNING: You’re trying to run this on 2000 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %%
sc.set_figure_params(facecolor='white')

# %%
from matplotlib import rcParams

# %%
rcParams['figure.figsize'] = [5, 5]
rcParams['figure.dpi'] = 130

# %%
sc.pl.umap(ad, color=['dataset', 'cell.type'], )
