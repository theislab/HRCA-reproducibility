# %% [markdown]
# ## Group samples by dataset, using increasing numbers of cells

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")
import scIB
import os
import scanpy as sc
from os.path import join
from os import listdir
import anndata
import numpy as np
import scipy

# %%
### Use the scran related directory to map all the files we need to put together.
datadir_orig = '/storage/groups/ml01/datasets/projects/20210318_retinal_data_integration_ignacio.ibarra_malte.luecken'
datadir_scran = '../../data/integration_march_2021/scran'
os.path.exists(datadir_orig), os.path.exists(datadir_scran)
# Out:
# (True, True)

# %%
# convert counts into float32
# Convenience method for computing the size of objects
def print_size_in_MB(x):
    print('{:.3} MB'.format(x.__sizeof__()/1e6))

filenames = [f for f in os.listdir(datadir_orig)]
filenames_md5 = [r.strip() for f in ['md5sum_chen_5_fix5.txt', 'md5sum.txt'] for r in open(os.path.join(datadir_orig, f))]

files = set()
for qi in filenames_md5:
    md5, fi = qi.split('  ')
    # print(fi)
    found = os.path.exists(os.path.join(datadir_scran, fi))
    if not found:
        print('not found', fi)
    files.add(fi)

# %%
filenames_by_dataset = {}
for f in filenames_md5:
    dataset, filename = f.split(' ')[-1].split('/')[-2:]
    if not dataset in filenames_by_dataset:
        filenames_by_dataset[dataset] = []
    filenames_by_dataset[dataset].append(filename)

# %%
filenames_by_dataset
# Out:
# {'Chen_a_fix5': ['10x3_Lobe_D005_13_NeuN.h5ad',
#   '10x3_Lobe_D013_13_NeuN.h5ad',
#   '10x_Lobe_D27_13_Nu.h5ad',
#   '10x_Lobe_D28_13_Nu.h5ad',
#   '10x_Lobe_D30_13_NeuN.h5ad'],
#  'Wong': ['Retina_3B.h5ad',
#   'Retina_2B.h5ad',
#   'Retina_1.h5ad',
#   'Retina_2A.h5ad',
#   'Retina_3A.h5ad'],
#  'Scheetz': ['GSM3745992.h5ad',
#   'GSM3745996.h5ad',
#   'GSM3745993.h5ad',
#   'GSM3745997.h5ad',
#   'GSM3745995.h5ad',
#   'GSM3745994.h5ad'],
#  'Roska': ['R-00646_03_Fovea_Retina_Left.h5ad',
#   'R-00646_04_Fovea_Retina_Right.h5ad',
#   'R-00646_04_Fovea_ChoroidRPE_Left.h5ad',
#   'R-00646_04_Periphery_ChoroidRPE_Left.h5ad',
#   'R-00646_07_Periphery_ChoroidRPE.h5ad',
#   'R-00646_03_Fovea_ChoroidRPE_Right.h5ad',
#   'R-00646_04_Periphery_Retina_Left.h5ad',
#   'R-00646_01_Periphery_ChoroidRPE_Left.h5ad',
#   'R-00646_03_Fovea_Retina_Right.h5ad',
#   'R-00646_03_Periphery_Retina_Right.h5ad',
#   'R-00646_07_Periphery_RetinaChoroidRPE.h5ad',
#   'R-00646_01_Periphery_Retina_Right.h5ad',
#   'R-00646_04_Fovea_ChoroidRPE_Right.h5ad',
#   'R-00646_07_Periphery_Retina.h5ad',
#   'R-00646_03_Periphery_ChoroidRPE_Left.h5ad',
#   'R-00646_04_Fovea_Retina_Left.h5ad',
#   'R-00646_01_Fovea_Retina_Right.h5ad',
#   'R-00646_01_Periphery_Retina_Left.h5ad',
#   'R-00646_03_Fovea_ChoroidRPE_Left.h5ad',
#   'R-00646_04_Periphery_Retina_Right.h5ad',
#   'R-00646_03_Periphery_Retina_Left.h5ad',
#   'R-00646_03_Periphery_ChoroidRPE_Right.h5ad',
#   'R-00646_01_Periphery_ChoroidRPE_Right.h5ad'],
#  'Chen_c': ['10x3_19_D008.h5ad',
#   '10x3_D019_13.h5ad',
#   '10x3_19_D010.h5ad',
#   '10x3_D027_13.h5ad',
#   '10x3_19_D019.h5ad',
#   '10x3_D005_13.h5ad',
#   '10x3_D009_13.h5ad',
#   '10x3_D026_13.h5ad',
#   '10x3_19_D005.h5ad',
#   '10x3_19_D009.h5ad',
#   '10x3_D018_13.h5ad',
#   '10x3_19_D011.h5ad',
#   '10x3_19_D003.h5ad',
#   '10x3_D028_13.h5ad',
#   '10x3_19_D007.h5ad',
#   '10x3_D030_13.h5ad',
#   '10x3_D017_13.h5ad',
#   '10x3_D013_13.h5ad',
#   '10x3_D021_13.h5ad',
#   '10x3_19_D006.h5ad'],
#  'Hafler': ['GSM4081525.h5ad',
#   'GSM4081529.h5ad',
#   'GSM4081528.h5ad',
#   'GSM4081524.h5ad',
#   'GSM4081526.h5ad',
#   'GSM4081527.h5ad'],
#  'Chen_a': ['10x3_Lobe_19_D006_NeuN.h5ad',
#   '10x3_Lobe_19_D007_NeuN.h5ad',
#   '10x3_Lobe_19_D010_Nu.h5ad',
#   '10x_Lobe_D026_13_NeuN.h5ad',
#   '10x_Lobe_D28_13_NeuN.h5ad',
#   '10x3_Lobe_19_D005_NeuN.h5ad',
#   '10x_Lobe_D19_13_Nu.h5ad',
#   '10x3_Lobe_19_D003_NeuN.h5ad',
#   '10x_Lobe_D28_13_Nu.h5ad',
#   '10x3_Lobe_19_D009_Nu.h5ad',
#   '10x3_Lobe_19_D005_Nu.h5ad',
#   '10x3_Lobe_D013_13_NeuN.h5ad',
#   '10x_Lobe_D018_26_13_Nu.h5ad',
#   '10x_Lobe_D30_13_Nu.h5ad',
#   '10x_Lobe_D27_13_NeuN.h5ad',
#   '10x3_Lobe_D009_13_Nu.h5ad',
#   '10x3_Lobe_19_D008_Nu.h5ad',
#   '10x_Lobe_D017_18_13_NeuN.h5ad',
#   '10x_Lobe_D21_13_Nu.h5ad',
#   '10x3_Lobe_19_D019_Nu.h5ad',
#   '10x3_Lobe_19_D011_Nu.h5ad',
#   '10x3_Lobe_19_D009_NeuN.h5ad',
#   '10x_Lobe_D21_13_NeuN.h5ad',
#   '10x3_Lobe_D013_13_Nu.h5ad',
#   '10x3_Lobe_D005_13_Nu.h5ad',
#   '10x_Lobe_D026_13_Nu.h5ad',
#   '10x3_Lobe_19_D008_NeuN.h5ad',
#   '10x_Lobe_D30_13_NeuN.h5ad',
#   '10x3_Lobe_19_D006_Nu.h5ad',
#   '10x_Lobe_D19_13_NeuN.h5ad',
#   '10x3_Lobe_19_D019_NeuN.h5ad',
#   '10x3_Lobe_D005_13_NeuN.h5ad',
#   '10x_Lobe_D018_26_13_NeuN.h5ad',
#   '10x_Lobe_D27_13_Nu.h5ad',
#   '10x3_Lobe_D009_13_NeuN.h5ad',
#   '10x3_Lobe_19_D011_NeuN.h5ad',
#   '10x3_Lobe_19_D010_NeuN.h5ad',
#   '10x3_Lobe_19_D007_Nu.h5ad',
#   '10x3_Lobe_19_D003_Nu.h5ad',
#   '10x_Lobe_D017_18_13_Nu.h5ad'],
#  'Sanes': ['H3CD90S1.h5ad',
#   'H3FoveaS1.h5ad',
#   'H2Fovea1S1.h5ad',
#   'H5FoveaS4.h5ad',
#   'H5FoveaS1.h5ad',
#   'H1CD90S1.h5ad',
#   'H5FoveaS5.h5ad',
#   'H3CD73dpS1.h5ad',
#   'H1CD73dpS1.h5ad',
#   'H5FoveaS3.h5ad',
#   'H3FoveaS2.h5ad',
#   'H4FoveaS1.h5ad',
#   'H3CD90S2.h5ad',
#   'H9FoveaS1.h5ad',
#   'H2Fovea2S1.h5ad',
#   'H3CD73dpS2.h5ad',
#   'H5FoveaS2.h5ad',
#   'H3FoveaS3.h5ad',
#   'H11FoveaS1.h5ad'],
#  'Hackney': ['GSM3988013.h5ad',
#   'GSM3988007.h5ad',
#   'GSM3988006.h5ad',
#   'GSM3988016.h5ad',
#   'GSM3988012.h5ad',
#   'GSM3988014.h5ad',
#   'GSM3988008.h5ad',
#   'GSM3988010.h5ad',
#   'GSM3988015.h5ad',
#   'GSM3988009.h5ad',
#   'GSM3988011.h5ad'],
#  'Chen_b': ['19D015_NeuNM.h5ad',
#   '19D015_NeuNT.h5ad',
#   '19D013_macular.h5ad',
#   '19D016_macular.h5ad',
#   '19D015_fovea.h5ad',
#   '19D015_macular.h5ad',
#   '19D014_fovea.h5ad',
#   '19D014_mac.h5ad',
#   '19D013_fovea.h5ad',
#   '19D013_NeuNT.h5ad',
#   '19D015_per.h5ad',
#   '17D013_NeuNT.h5ad',
#   'D001-12_NeuNT.h5ad',
#   'D001-12_NeuNM.h5ad',
#   '19D014_NeuNT.h5ad']}

# %% [markdown]
# This function returns datasets per code, concatenated

# %%
def get_by_dataset(dataset_name, filenames=None, n_sample=None):
    adatas = []
    
    if (filenames is None):
        filenames = [f for f in listdir(join(datadir_scran, dataset_name))]
    print('# datasets', len(filenames))
    for i, f in enumerate(filenames):
        if len(adatas) % 20 == 0:
            print('loaded so far', len(adatas))

        p = join(datadir_scran, dataset_name, f)
                    
        fix5_path = p.replace('Chen_a', 'Chen_a_fix5')
        if os.path.exists(fix5_path):
            # print(os.path.exists(fix5_path), fix5_path)
            print('replace this path')
            print(p)
            p = fix5_path
            print('by this path')
        
        print(i, n_sample, p)
        ad = sc.read_h5ad(p)
        
        if n_sample is not None:
            print('subsampling')
            idx_sample = ad.obs.sample(n_sample if n_sample < ad.shape[0] else ad.shape[0]).index
            ad = ad[ad.obs.index.isin(idx_sample),:]
            # print(ad.shape)        
            
        ad.obs['dataset'] = dataset_name
        ad.obs['filename'] = f.replace('.h5ad', '')
        adatas.append(ad)
    return adatas[0].concatenate(adatas[1:]) # join='outer')

# %%
from os.path import exists
for n_sample in [250, 500, 1000, None]:
    if n_sample != 500 and n_sample != None:
        continue
    for dataset in filenames_by_dataset:
        
        if dataset == 'Chen_a_fix5':
            continue
        
        print(dataset)

        subsampling_code = ('_' + str(n_sample) if n_sample is not None else '')
        next_filename = '%s%s.h5ad' % (dataset, subsampling_code)
        outdir = '../../data/integration_march_2021/input/bydataset%s' % subsampling_code
        if not exists(outdir):
            os.mkdir(outdir)
        
        path_by_dataset = join(outdir, '%s' % (next_filename))
        
        if exists(path_by_dataset):
            continue
        
        ad = get_by_dataset(dataset, filenames=filenames_by_dataset[dataset])
        if n_sample is not None:
            sel_idx = ad.obs.groupby('batch').apply(lambda x: x.sample(min(n_sample, len(x)))).index.get_level_values(None)
            ad = ad[ad.obs.index.isin(sel_idx),:]
            # print(ad.obs.batch.value_counts())
            print(ad.shape)
        
        print(ad.shape)
        ad.write(path_by_dataset, compression='lzf')
        print(dataset, 'done...')
# Out:
# Wong
# Scheetz
# Roska
# Chen_c
# Hafler
# Chen_a
# # datasets 40
# loaded so far 0
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D006_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D006_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D007_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D007_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D010_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D010_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D026_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D026_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D28_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D28_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D005_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D005_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D19_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D19_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D003_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D003_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D28_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a_fix5/10x_Lobe_D28_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D009_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D009_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D005_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D005_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D013_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a_fix5/10x3_Lobe_D013_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D018_26_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D018_26_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D30_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D30_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D27_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D27_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D009_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D009_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D008_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D008_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D017_18_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D017_18_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D21_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D21_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D019_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D019_Nu.h5ad
# loaded so far 20
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D011_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D011_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D009_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D009_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D21_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D21_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D013_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D013_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D005_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D005_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D026_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D026_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D008_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D008_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D30_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a_fix5/10x_Lobe_D30_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D006_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D006_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D19_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D19_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D019_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D019_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D005_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a_fix5/10x3_Lobe_D005_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D018_26_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D018_26_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x_Lobe_D27_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a_fix5/10x_Lobe_D27_13_Nu.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D009_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_D009_13_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D011_NeuN.h5ad
# ../../data/integration_march_2021/scran/Chen_a/10x3_Lobe_19_D011_NeuN.h5ad
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-3f40c510443c> in <module>
#      22
#      23
# ---> 24         ad = get_by_dataset(dataset, filenames=filenames_by_dataset[dataset])
#      25
#      26         assert False
#
# <ipython-input-24-af0d606e4c6c> in get_by_dataset(dataset_name, filenames, n_sample)
#      18
#      19         print(p)
# ---> 20         ad = sc.read_h5ad(p)
#      21
#      22         if n_sample is not None:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_io/h5ad.py in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     419                 d[k] = read_dataframe(f[k])
#     420             else:  # Base case
# --> 421                 d[k] = read_attribute(f[k])
#     422
#     423         d["raw"] = _read_raw(f, as_sparse, rdasp)
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/functools.py in wrapper(*args, **kw)
#     838                             '1 positional argument')
#     839
# --> 840         return dispatch(args[0].__class__)(*args, **kw)
#     841
#     842     funcname = getattr(func, '__name__', 'singledispatch function')
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_io/utils.py in func_wrapper(elem, *args, **kwargs)
#     175     def func_wrapper(elem, *args, **kwargs):
#     176         try:
# --> 177             return func(elem, *args, **kwargs)
#     178         except Exception as e:
#     179             if isinstance(e, AnnDataReadError):
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_io/h5ad.py in read_group(group)
#     533         return read_dataframe(group)
#     534     elif encoding_type in {"csr_matrix", "csc_matrix"}:
# --> 535         return SparseDataset(group).to_memory()
#     536     else:
#     537         raise ValueError(f"Unfamiliar `encoding-type`: {encoding_type}.")
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/sparse_dataset.py in to_memory(self)
#     369         format_class = get_memory_class(self.format_str)
#     370         mtx = format_class(self.shape, dtype=self.dtype)
# --> 371         mtx.data = self.group["data"][...]
#     372         mtx.indices = self.group["indices"][...]
#     373         mtx.indptr = self.group["indptr"][...]
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/h5py/_hl/dataset.py in __getitem__(self, args, new_dtype)
#     785         mspace = h5s.create_simple(selection.mshape)
#     786         fspace = selection.id
# --> 787         self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     788
#     789         # Patch up the output for NumPy
#
# KeyboardInterrupt:

# %% [markdown]
# ### The following snippet merges old and new Chen_a_fix5 recounted samples with the old Chen_a samples

# %%
print('obsolete')
assert False

# %%
import scanpy as sc
for n_sample in [250, 500, 1000, None]:
    if n_sample != 500 and n_sample != None:
        continue
    
    subsampling_code = ('_' + str(n_sample) if n_sample is not None else '')
    log_path = os.path.join('../../data/integration_march_2021/input/bydataset%s' % subsampling_code, 'merged.txt')
    if not os.path.exists(log_path):
        outdir = '../../data/integration_march_2021/input/bydataset%s' % subsampling_code
        
        path_chen_fix = os.path.join(outdir, 'Chen_a_fix5%s.h5ad' % subsampling_code)
        path_chen_old = os.path.join(outdir, 'Chen_a%s.h5ad' % subsampling_code)
        
        print(os.path.exists(path_chen_fix), path_chen_fix)
        print(os.path.exists(path_chen_old), path_chen_old)
        
        ad_chen_fix = sc.read_h5ad(path_chen_fix)
        ad_chen_old = sc.read_h5ad(path_chen_old)
        print(ad_chen_fix.shape, ad_chen_old.shape)
        ad_chen_others = ad_chen_old[~ad_chen_old.obs['filename'].isin(set(ad_chen_fix.obs['filename']))]
        print(ad_chen_others.shape, ad_chen_fix.shape)
        ad_chen = ad_chen_fix.concatenate(ad_chen_others)
        ad_chen.write(os.path.join(outdir, 'Chen_a_fix5%s.h5ad' % subsampling_code))
        print(ad_chen.obs['filename'].value_counts())
        writer = open(log_path, 'w')
        writer.write('chen new samples and old samples have been merged\n')
        writer.close()
    else:
        print(n_sample, 'skip...')
# Out:
# 500 skip...
# True ../../data/integration_march_2021/input/bydataset/Chen_a_fix5.h5ad
# True ../../data/integration_march_2021/input/bydataset/Chen_a.h5ad
# (198265, 28685) (1338345, 14560)
# (1143648, 14560) (198265, 28685)
