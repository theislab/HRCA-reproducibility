# %% [markdown]
# ### Plot the embeddings of multiple integrations of Chen + X at the same time

# %%
import scIB
import numpy as np
import scanpy as sc
# ls -ltrh /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/input/input*_cells.h5ad
import os
from os.path import exists, join
from os import makedirs, listdir
import pandas as pd
# ad = sc.read_h5ad('/home/icb/ignacio.ibarra/theislab/scIB_output/retinal_all_batch_donor_dataset_cell.type/prepare/unscaled/HVG.2K/adata_pre.h5ad')
# ad.shape
### here we write a version of the script in where we are sampling Chen_a/b/c
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %%
import anndata
from os.path import abspath
from os.path import basename

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
rcParams['figure.dpi'] = 150

# %%
basedir = '/mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output'
for d in listdir(basedir):
    if 'retinal_all_' in d:
        if not os.path.isdir(join(basedir, d)):
            continue
        p = join(basedir, d)
        
        for method in ['scvi_embed.csv', 'scgen_full.csv', 'scanvi_embed.csv']:
            embed_path = join(p, 'embeddings', 'unscaled', 'HVG.1K', method)
            print(d, exists(embed_path), basename(embed_path))
            print(abspath(embed_path))
            continue
# Out:
# retinal_all_all_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_all_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_all_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_all_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_all_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_all_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen+Wong_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Wong_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen+Wong_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Wong_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen+Wong_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Wong_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen+Sanes_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Sanes_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen+Sanes_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Sanes_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen+Sanes_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Sanes_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen+Hackney_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen+Hackney_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen+Hackney_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen+Hafler_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hafler_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen+Hafler_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hafler_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen+Hafler_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hafler_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen+Roska_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Roska_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen+Roska_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Roska_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen+Roska_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Roska_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv
# retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type True scvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scvi_embed.csv
# retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type True scgen_full.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scgen_full.csv
# retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type True scanvi_embed.csv
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv

# %% [markdown]
# ### Dataset permutations

# %%
basedir = '/mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_all_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K'
queries = []
for f in listdir(basedir):
    if not 'scvi_2000000_25' in f or not '.csv' in f:
        continue
    dataset_names = ['Hackney', 'Hafler', 'Roska', 'Wong', 'Scheetz', 'Sanes']
    
    for dataset in dataset_names:
        if not dataset in f:
            continue
        queries.append([dataset, f, ])
    continue
    if 'retinal_all_' in d:
        if not os.path.isdir(join(basedir, d)):
            continue
        # print(d)
        p = join(basedir, d)
        
        for method in ['scvi_embed.csv', 'scgen_full.csv', 'scanvi_embed.csv']:
            embed_path = join(p, 'embeddings', 'unscaled', 'HVG.1K', method)

            print(d, exists(embed_path), basename(embed_path))

            if not exists(embed_path):
                continue      
                
            continue
            # print(exists(png_path), embed_path)
            # ax = plt.subplot(1, 2, 1)
            # embed = pd.read_csv(embed_path, nrows=1000)
            embed = pd.read_csv(embed_path)

            print(embed.shape)
            ad = anndata.AnnData(obs=embed)
            sc.set_figure_params(facecolor='white')
            ad.obsm['X_umap'] = ad.obs[['UMAP1', 'UMAP2']].to_numpy()

            query_name = basename(d).split('_')[2]
            n_cells = "+".join(map(str, ad.obs['batch_donor_dataset'].str.split('_').str[0].value_counts().values))
            sc.pl.embedding(ad, 'X_umap', title=query_name + '\n' + method + '\n' + n_cells, color='cell.type')
        print('\n\n')

# %%
# grp.drop_duplicates('filename')

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = 30, 20
rcParams['figure.dpi'] = 150

df = pd.DataFrame(queries, columns=['dataset', 'filename'])
df['n.dataset'] = df.filename.str.replace('scvi_2000000_25_', '').str.replace('_embed.csv', '').str.split('_').str.len()


for dataset, grp in df.groupby('dataset'):
    if dataset != 'Roska':
        continue
    grp = grp.sort_values('n.dataset', ascending=True)
    print(dataset, grp.shape)

    ncols = 4
    fig, ax = plt.subplots(nrows = int(grp.shape[0] / ncols) + 1, ncols=ncols)
    ax = ax.flatten()
    
    n_sample = None # 2000
    for ei, embed_filename in enumerate(grp['filename']):
        print(ei, embed_filename)
        embed_path = join(basedir, embed_filename)
        embed = pd.read_csv(embed_path, nrows=n_sample)
        
        ad = anndata.AnnData(obs=embed.head(n_sample) if n_sample is not None else embed)
        sc.set_figure_params(facecolor='white')
        ad.obsm['X_umap'] = ad.obs[['UMAP1', 'UMAP2']].to_numpy()
        # query_name = basename(d).split('_')[2]
        # n_cells = "+".join(map(str, ad.obs['batch_donor_dataset'].str.split('_').str[0].value_counts().values))
        
        title = ",".join([s[:3] for s in embed_filename.replace('scvi_2000000_25_', '').replace('_embed.csv', '').split('_')])
        sc.pl.embedding(ad, 'X_umap', color='cell.type', ax=ax[ei], show=ei + 1 == grp.shape[0],
                       legend_loc=None, frameon=False, title=title)
        

    break
# Out:
# Roska (25, 3)
# 0 scvi_2000000_25_Roska_Sanes_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 1 scvi_2000000_25_Roska_Wong_Sanes_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 2 scvi_2000000_25_Roska_Hackney_Wong_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 3 scvi_2000000_25_Scheetz_Sanes_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 4 scvi_2000000_25_Roska_Wong_Hackney_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 5 scvi_2000000_25_Wong_Sanes_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 6 scvi_2000000_25_Sanes_Roska_Hafler_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 7 scvi_2000000_25_Sanes_Wong_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 8 scvi_2000000_25_Sanes_Scheetz_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 9 scvi_2000000_25_Scheetz_Roska_Sanes_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 10 scvi_2000000_25_Hackney_Hafler_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 11 scvi_2000000_25_Scheetz_Hackney_Hafler_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 12 scvi_2000000_25_Hackney_Roska_Sanes_Wong_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 13 scvi_2000000_25_Scheetz_Roska_Sanes_Hackney_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 14 scvi_2000000_25_Sanes_Hafler_Roska_Wong_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 15 scvi_2000000_25_Hackney_Roska_Scheetz_Hafler_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 16 scvi_2000000_25_Sanes_Hackney_Roska_Scheetz_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 17 scvi_2000000_25_Roska_Wong_Sanes_Scheetz_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 18 scvi_2000000_25_Hackney_Sanes_Scheetz_Roska_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 19 scvi_2000000_25_Roska_Sanes_Wong_Hackney_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 20 scvi_2000000_25_Hackney_Hafler_Roska_Wong_Scheetz_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 21 scvi_2000000_25_Wong_Hafler_Hackney_Roska_Sanes_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 22 scvi_2000000_25_Sanes_Hafler_Hackney_Roska_Wong_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 23 scvi_2000000_25_Wong_Scheetz_Hafler_Roska_Hackney_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# 24 scvi_2000000_25_Hafler_Hackney_Roska_Scheetz_Sanes_embed.csv
# ... storing 'cell.type' as categorical
# ... storing 'batch_donor_dataset' as categorical
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-8-414d0b987e07> in <module>
#      32         sc.pl.embedding(ad, 'X_umap', color='cell.type', ax=ax[ei], show=ei + 1 == grp.shape[0],
# ---> 33                        legend_loc=None, frameon=False, title=title)
#      34
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/scanpy/plotting/_tools/scatterplots.py in embedding(adata, basis, color, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, **kwargs)
#     448     axs = axs if grid else ax
# --> 449     _utils.savefig_or_show(basis, show=show, save=save)
#     450     if show is False:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/scanpy/plotting/_utils.py in savefig_or_show(writekey, show, dpi, ext, save)
#     313     if show:
# --> 314         pl.show()
#     315     if save:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kwargs)
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41                 figure_manager.canvas.figure,
# ---> 42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      43             )
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     249     if 'retina' in formats or 'png2x' in formats:
# --> 250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#     251     if 'jpg' in formats or 'jpeg' in formats:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/pylabtools.py in retina_figure(fig, **kwargs)
#     139     """format a figure as a pixel-doubled (retina) PNG"""
# --> 140     pngdata = print_figure(fig, fmt='retina', **kwargs)
#     141     # Make sure that retina_figure acts just like print_figure and returns
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
# --> 509         FigureCanvasAgg.draw(self)
#     510         mpl.image.imsave(
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     930         self.set_sizes(self._sizes, self.figure.dpi)
# --> 931         Collection.draw(self, renderer)
#     932
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     411                 self._antialiaseds, self._urls,
# --> 412                 self._offset_position)
#     413
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path_collection(self, gc, master_transform, paths, all_transforms, offsets, offsetTrans, facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls, offset_position)
#     174             facecolors, edgecolors, linewidths, linestyles, antialiaseds, urls,
# --> 175             offset_position)
#     176
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/matplotlib/path.py in vertices(self)
#     201
# --> 202     @property
#     203     def vertices(self):
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1100             # (5 blanks lines) where none should be returned.
# -> 1101             return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#    1102         except UnicodeDecodeError:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in wrapped(*args, **kwargs)
#     247         try:
# --> 248             return f(*args, **kwargs)
#     249         finally:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in _fixed_getinnerframes(etb, context, tb_offset)
#     280
# --> 281     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#     282     # If the error is at the console, don't build any context, since it would
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/inspect.py in getinnerframes(tb, context)
#    1501     while tb:
# -> 1502         frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#    1503         framelist.append(FrameInfo(*frameinfo))
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/inspect.py in getframeinfo(frame, context)
#    1463         try:
# -> 1464             lines, lnum = findsource(frame)
#    1465         except OSError:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in findsource(object)
#     181             globals_dict = module.__dict__
# --> 182     lines = linecache.getlines(file, globals_dict)
#     183     if not lines:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in updatecache(filename, module_globals)
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in open(filename)
#     448     try:
# --> 449         encoding, lines = detect_encoding(buffer.readline)
#     450         buffer.seek(0)
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in detect_encoding(readline)
#     417
# --> 418     first = read_or_stop()
#     419     if first.startswith(BOM_UTF8):
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in read_or_stop()
#     375         try:
# --> 376             return readline()
#     377         except StopIteration:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2063                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1078         head = self.prepare_header(etype, self.long_header)
# -> 1079         records = self.get_records(etb, number_of_lines_of_context, tb_offset)
#    1080
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/ultratb.py in get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1115             inspect_error()
# -> 1116             traceback.print_exc(file=self.ostream)
#    1117             info('\nUnfortunately, your original traceback can not be constructed.\n')
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in print_exc(limit, file, chain)
#     162     """Shorthand for 'print_exception(*sys.exc_info(), limit, file)'."""
# --> 163     print_exception(*sys.exc_info(), limit=limit, file=file, chain=chain)
#     164
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in print_exception(etype, value, tb, limit, file, chain)
#     103     for line in TracebackException(
# --> 104             type(value), value, tb, limit=limit).format(chain=chain):
#     105         print(line, file=file, end="")
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     520         if lookup_lines:
# --> 521             self._load_lines()
#     522
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     532         if self.__context__:
# --> 533             self.__context__._load_lines()
#     534         if self.__cause__:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     532         if self.__context__:
# --> 533             self.__context__._load_lines()
#     534         if self.__cause__:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     530         for frame in self.stack:
# --> 531             frame.line
#     532         if self.__context__:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in line(self)
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in updatecache(filename, module_globals)
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in open(filename)
#     448     try:
# --> 449         encoding, lines = detect_encoding(buffer.readline)
#     450         buffer.seek(0)
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in detect_encoding(readline)
#     417
# --> 418     first = read_or_stop()
#     419     if first.startswith(BOM_UTF8):
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in read_or_stop()
#     375         try:
# --> 376             return readline()
#     377         except StopIteration:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2074
#    2075         except KeyboardInterrupt:
# -> 2076             print('\n' + self.get_exception_only(), file=sys.stderr)
#    2077
#    2078     def _showtraceback(self, etype, evalue, stb):
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/site-packages/IPython/core/interactiveshell.py in get_exception_only(self, exc_tuple)
#    2019         """
#    2020         etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2021         msg = traceback.format_exception_only(etype, value)
#    2022         return ''.join(msg)
#    2023
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in format_exception_only(etype, value)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#     141
#     142
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     519             self.msg = exc_value.msg
#     520         if lookup_lines:
# --> 521             self._load_lines()
#     522
#     523     @classmethod
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     531             frame.line
#     532         if self.__context__:
# --> 533             self.__context__._load_lines()
#     534         if self.__cause__:
#     535             self.__cause__._load_lines()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     531             frame.line
#     532         if self.__context__:
# --> 533             self.__context__._load_lines()
#     534         if self.__cause__:
#     535             self.__cause__._load_lines()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     531             frame.line
#     532         if self.__context__:
# --> 533             self.__context__._load_lines()
#     534         if self.__cause__:
#     535             self.__cause__._load_lines()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in _load_lines(self)
#     529         """Private API. force all lines in the stack to be loaded."""
#     530         for frame in self.stack:
# --> 531             frame.line
#     532         if self.__context__:
#     533             self.__context__._load_lines()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/traceback.py in line(self)
#     283     def line(self):
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#     287
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      14
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      45
#      46     try:
# ---> 47         return updatecache(filename, module_globals)
#      48     except MemoryError:
#      49         clearcache()
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/linecache.py in updatecache(filename, module_globals)
#     134             return []
#     135     try:
# --> 136         with tokenize.open(fullname) as fp:
#     137             lines = fp.readlines()
#     138     except OSError:
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in open(filename)
#     447     buffer = _builtin_open(filename, 'rb')
#     448     try:
# --> 449         encoding, lines = detect_encoding(buffer.readline)
#     450         buffer.seek(0)
#     451         text = TextIOWrapper(buffer, encoding, line_buffering=True)
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in detect_encoding(readline)
#     416         return encoding
#     417
# --> 418     first = read_or_stop()
#     419     if first.startswith(BOM_UTF8):
#     420         bom_found = True
#
# ~/miniconda3/envs/scIB-python/lib/python3.7/tokenize.py in read_or_stop()
#     374     def read_or_stop():
#     375         try:
# --> 376             return readline()
#     377         except StopIteration:
#     378             return b''
#
# KeyboardInterrupt:

# %% [markdown]
# ### Attempt PAGA in an integrated sample.

# %%
data_dir = '/mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration'

# %%
from os.path import join
import pandas as pd
import scanpy as sc
import anndata

# %%
# print(exists(png_path), embed_path)
# ax = plt.subplot(1, 2, 1)
# embed = pd.read_csv(embed_path, nrows=1000)
embed_path = join(data_dir, 'data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv')
adata_path = join(data_dir, 'data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K/scanvi.h5ad')
embed = pd.read_csv(embed_path)

print(embed.shape)
# ad = anndata.AnnData(obs=embed)
sc.set_figure_params(facecolor='white')
# Out:
# (1907304, 5)

# %%
adata = sc.read_h5ad(adata_path)

# %%
ad_embed = anndata.AnnData(obs=embed)
adata.obsm['X_umap'] = ad_embed.obs[['UMAP1', 'UMAP2']].to_numpy()
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/anndata.py:120: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
sc.pl.umap(adata, color='cell.type')

# %%
assert ad_embed.shape[0] == adata.shape[0]

# %%
print(embed_path)
# Out:
# /mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/embeddings/unscaled/HVG.1K/scanvi_embed.csv

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_emb, X_umap

# %%
n_ac_and_bc = adata[adata.obs['cell.type'].isin({'AC', 'BC'}),:].obs_names.shape[0]
n_sample = 100000 # n_ac_and_bc # 100000
sample_idx = pd.Series(adata[adata.obs['cell.type'].isin({'AC', 'BC'}),:].obs_names).sample(n_sample, random_state=500)
ad = adata[adata.obs_names.isin(sample_idx),:]
ad.shape
# Out:
# (100000, 1000)

# %% [markdown]
# ### To compare with the unintegrated data, we need to load it and use this as a ref object

# %%
adata_unintegrated_path = join('/mnt/znas/icb_zstore01/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data',
                               'integration_march_2021/output/retinal_all_all_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad')
adata_unintegrated = sc.read_h5ad(adata_unintegrated_path)

# %%
adata_unintegrated.shape

# %%
ad_unintegrated = adata_unintegrated[adata_unintegrated.obs_names.isin(sample_idx),:]

# %%
scIB.metrics.metrics(
    adata=ad_unintegrated,
    adata_int=ad_integrated,
    batch_key='batch_donor_dataset',
    label_key='cell.type',
    hvg_score_=False,
    # cluster_key='cluster',
    # cluster_nmi='abc/test.csv',
    ari_=True,
    nmi_=True,
    nmi_method='arithmetic',
    nmi_dir='abc/test.csv',
    silhouette_=True,
    embed='X_pca',
    si_metric='euclidean',
    pcr_=True,
    # cell_cycle_=False,
    # cell_cycle_complex_=False,
#     organism='mouse',
    isolated_labels_=True,  # backwards compatibility
    # isolated_labels_f1_=False,
    # isolated_labels_asw_=False,
    n_isolated=None,
    graph_conn_=False,
    # kBET_=False,
    # subsample=0.5,
#     lisi_graph_=False,
#     ilisi_=False,
#     clisi_=False,
    trajectory_=False,
    type_=None,
    verbose=False,
)
