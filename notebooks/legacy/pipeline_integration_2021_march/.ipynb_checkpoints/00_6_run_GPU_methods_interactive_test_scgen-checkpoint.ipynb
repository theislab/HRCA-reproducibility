# %%
# %load_ext autoreload
# %autoreload 2

# %%
import scIB
import numpy as np
import scanpy as sc
# ls -ltrh /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/input/input*_cells.h5ad
import os
from os.path import exists, join
from os import makedirs
import pandas as pd
# ad = sc.read_h5ad('/home/icb/ignacio.ibarra/theislab/scIB_output/retinal_all_batch_donor_dataset_cell.type/prepare/unscaled/HVG.2K/adata_pre.h5ad')
# ad.shape
### here we write a version of the script in where we are sampling Chen_a/b/c
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
import scIB
scIB.__file__
# Out:
# '/home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/scIB/__init__.py'

# %%
import sys

print(sys.argv)
query = sys.argv[1] # 'heart_ventricle' # 'heart_ventricle', 'heart_atrial'

if query == '-f':
    query = 0
else:
    query = int(query) - 1

# read queries from dataframe path
df = pd.read_csv('queries_gpu_methods.csv', index_col=0)
# Out:
# ['/home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/ipykernel_launcher.py', '-f', '/mnt/home/icb/ignacio.ibarra/.local/share/jupyter/runtime/kernel-29649edd-36c4-43a8-8594-af2f0fdb99e4.json']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2eb61a4a81bc> in <module>
#      10
#      11 # read queries from dataframe path
# ---> 12 df = pd.read_csv('queries_gpu_methods.csv', index_col=0)
#
# NameError: name 'pd' is not defined

# %%
# print(df)
for p in  df['input']:
    print(exists(p), p)
# Out:
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hafler_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Roska_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Sanes_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Wong_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hackney_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Scheetz_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Roska_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Sanes_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Wong_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_all_Chen+Hafler_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad

# %%
print('query', query)
method, hvg, cell_type_key, input_path, output_path = df.iloc[query]
# Out:
# query 0

# %%
ad.shape
# Out:
# (69631, 1000)

# %%
from tensorflow.python.client import device_lib
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 32076188877
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 1208384059397874064
# physical_device_desc: "device: 0, name: Tesla V100-SXM3-32GB, pci bus id: 0000:91:00.0, compute capability: 7.0"

# %%
import scgen
# VAEArith

# %%
print('here...')
# Out:
# here...

# %%
devices[3]
# Out:
# name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 32076188877
# locality {
#   bus_id: 2
#   numa_node: 1
#   links {
#   }
# }
# incarnation: 9651611356236055571
# physical_device_desc: "device: 0, name: Tesla V100-SXM3-32GB, pci bus id: 0000:91:00.0, compute capability: 7.0"

# %%
devices = device_lib.list_local_devices()

# %%
ad.shape
# Out:
# (69631, 1000)

# %%
ad = sc.read_h5ad('/storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_500_all_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad')
ad.to_df()
# Out:
#                                     RLBP1      SPP1      GLUL      FRZB  \
# CELL3980150-0:Hackney:0          0.000000  0.000000  0.000000  0.000000
# CELL3980173-0:Hackney:0          0.000000  0.000000  0.000000  0.000000
# CELL3980184-0:Hackney:0          0.000000  0.000000  0.000000  0.000000
# CELL3980226-0:Hackney:0          0.000000  0.000000  0.000000  0.224607
# CELL3980300-0:Hackney:0          0.000000  0.000000  0.000000  0.000000
# ...                                   ...       ...       ...       ...
# TTTGACTCACAGTCCG-1-39:Chen_a:39  0.568465  0.000000  0.000000  0.000000
# TTTGACTGTTGTTTGG-1-39:Chen_a:39  0.000000  0.000000  0.400946  0.000000
# TTTGATCGTTCTTCAT-1-39:Chen_a:39  0.000000  1.732645  0.000000  0.000000
# TTTGGTTCAATAGGAT-1-39:Chen_a:39  0.000000  0.000000  0.000000  1.132080
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39  0
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39   0.0  0.000000  0.000000
#
# [69631 rows x 1000 columns]

# %%
ad2 = sc.read_h5ad('/storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_500_all_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K/scgen.h5ad')
ad2.shape
# Out:
# (69631, 1000)

# %%
ad2.to_df()
# Out:
#                                     RLBP1      SPP1      GLUL      FRZB  \
# CELL3980150-0:Hackney:0          0.044493  0.012383  0.223729  0.127899
# CELL3980173-0:Hackney:0         -0.022038  0.070942  0.018329 -0.018251
# CELL3980184-0:Hackney:0         -0.057055  0.107690  0.080245 -0.038962
# CELL3980226-0:Hackney:0         -0.037006  0.208102  0.055711  0.013400
# CELL3980300-0:Hackney:0         -0.099080 -0.061189  0.136412  0.003383
# ...                                   ...       ...       ...       ...
# TTTGACTCACAGTCCG-1-39:Chen_a:39  0.146325  0.095476  0.044802  0.090684
# TTTGACTGTTGTTTGG-1-39:Chen_a:39 -0.122305 -0.128742  0.118380 -0.069369
# TTTGATCGTTCTTCAT-1-39:Chen_a:39  0.292423  0.647192  0.190080  0.111217
# TTTGGTTCAATAGGAT-1-39:Chen_a:39 -0.141845  0.049835 -0.012075  0.205889
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39  0.209266 -0.012660  0.225519  0.095390
#
#                                       CLU   C1orf61      MEG3      HES1  \
# CELL3980150-0:Hackney:0          1.473278  0.065023  2.142694  0.130812
# CELL3980173-0:Hackney:0          1.398837  0.071163  2.757581 -0.017366
# CELL3980184-0:Hackney:0          1.268999  0.049005  2.619731 -0.039428
# CELL3980226-0:Hackney:0          1.276200  0.057026  2.597182 -0.005980
# CELL3980300-0:Hackney:0         -0.056654 -0.055862 -0.000338  0.008117
# ...                                   ...       ...       ...       ...
# TTTGACTCACAGTCCG-1-39:Chen_a:39  0.091191  0.166981  0.115388 -0.020646
# TTTGACTGTTGTTTGG-1-39:Chen_a:39 -0.132770 -0.076358  1.913038 -0.055462
# TTTGATCGTTCTTCAT-1-39:Chen_a:39  0.299213  0.321652 -0.010051  0.358911
# TTTGGTTCAATAGGAT-1-39:Chen_a:39 -0.072276 -0.146640 -0.029540 -0.087438
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39  0.082969  0.111767  0.047082  0.026338
#
#                                     RGS16     NEAT1  ...     DHRS7    ZNHIT2  \
# CELL3980150-0:Hackney:0          0.179362  2.371229  ...  0.547519  0.077042
# CELL3980173-0:Hackney:0          0.118603  2.778748  ...  0.568812  0.085114
# CELL3980184-0:Hackney:0          0.072289  2.698880  ...  0.624941  0.085171
# CELL3980226-0:Hackney:0          0.249025  2.640219  ...  0.571483  0.078881
# CELL3980300-0:Hackney:0         -0.030535  0.037482  ...  0.573018  0.064590
# ...                                   ...       ...  ...       ...       ...
# TTTGACTCACAGTCCG-1-39:Chen_a:39  0.140787  0.233863  ...  0.227128  0.064710
# TTTGACTGTTGTTTGG-1-39:Chen_a:39 -0.066496  1.600977  ...  0.002408  0.005674
# TTTGATCGTTCTTCAT-1-39:Chen_a:39  0.086859  0.238365  ...  0.179481  0.085574
# TTTGGTTCAATAGGAT-1-39:Chen_a:39  0.023385 -0.066468  ...  0.588446  0.062381
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39  0.057814  0.126391  ...  0.151050  0.089433
#
#                                    COMMD6      BEX5     IQCB1     NOP10  \
# CELL3980150-0:Hackney:0          0.666261  0.703977  0.081572  0.609426
# CELL3980173-0:Hackney:0          0.717523  0.713980  0.072300  0.645701
# CELL3980184-0:Hackney:0          0.726102  0.713882  0.073747  0.650937
# CELL3980226-0:Hackney:0          0.707092  0.679474  0.075022  0.619910
# CELL3980300-0:Hackney:0          0.126833  0.113966  0.063918  0.172208
# ...                                   ...       ...       ...       ...
# TTTGACTCACAGTCCG-1-39:Chen_a:39  0.237240  0.102032  0.124444  0.114407
# TTTGACTGTTGTTTGG-1-39:Chen_a:39 -0.046364 -0.023594  0.170837 -0.011615
# TTTGATCGTTCTTCAT-1-39:Chen_a:39  0.363262  0.043342  0.039721  0.130716
# TTTGGTTCAATAGGAT-1-39:Chen_a:39  0.148929  0.094001  0.061594  0.176805
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39  0.249118  0.069363  0.049179  0.141584
#
#                                    SEC11C      NXT1   ADIPOR1      UBN1
# CELL3980150-0:Hackney:0          0.631568  0.110732  0.207341  0.211058
# CELL3980173-0:Hackney:0          0.681431  0.115945  0.216585  0.161642
# CELL3980184-0:Hackney:0          0.693720  0.117061  0.214729  0.153005
# CELL3980226-0:Hackney:0          0.653215  0.111997  0.206267  0.141885
# CELL3980300-0:Hackney:0          0.324348  0.106751  0.378205  0.137929
# ...                                   ...       ...       ...       ...
# TTTGACTCACAGTCCG-1-39:Chen_a:39  0.257192  0.074620  0.312252  0.189731
# TTTGACTGTTGTTTGG-1-39:Chen_a:39 -0.007099 -0.015642  0.029760  0.147975
# TTTGATCGTTCTTCAT-1-39:Chen_a:39  0.198592  0.095450  0.287316  0.093856
# TTTGGTTCAATAGGAT-1-39:Chen_a:39  0.226473  0.141153  0.393904  0.096775
# TTTGTTGAGGCGAAGG-1-39:Chen_a:39  0.231823  0.098570  0.343091  0.140710
#
# [69631 rows x 1000 columns]

# %%
ad = sc.read_h5ad('/storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_500_all_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad')
adata = ad
sc.tl.pca(adata)
print('neighbors')
sc.pp.neighbors(adata)
print('umap')
sc.tl.umap(adata)
sc.pl.umap(adata, color=['dataset', 'cell.type'])
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/anndata.py:1056: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# neighbors
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../../../home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))
# umap

# %%
devices = device_lib.list_local_devices()
for di, device in enumerate(devices):
    if device.name.split(':')[1] != 'GPU':
        continue
    print(di, device.name)
    # ad.shape
    ad = sc.read_h5ad('/storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_500_all_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad')
    # ad = ad[ad.obs.index.isin(pd.Series(ad.obs.index).sample(10000)),:]
    adata = ad

    cell_type_key = 'cell.type'
    print(ad.shape)
    batch = 'batch_donor_dataset'
    integrated = scIB.integration.runScGen(adata, batch, cell_type_key, epochs=100, device=str(di))
    break

# %%
import scanpy as sc
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
adata = sc.read_h5ad('/storage/groups/ml01/workspace/ignacio.ibarra/theislab/retinal_scRNAseq_integration/data/integration_march_2021/output/retinal_500_all_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K/scgen.h5ad')
adata.shape
# sc.pp.neighbors(adata, use_rep='latent')
# sc.tl.umap(adata)

# sc.pl.umap(adata, color=['dataset', 'cell.type'])
# Out:
# (69631, 1000)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 69631 × 1000
#     obs: 'RNA_snn_res.0.8', 'batch', 'batch.merged', 'batch_donor_dataset', 'cell.type', 'dataset', 'donor', 'filename', 'nCount_RNA', 'nFeature_RNA', 'orig.ident', 'scpred_AC', 'scpred_Astrocyte', 'scpred_BC', 'scpred_Cone', 'scpred_HC', 'scpred_MG', 'scpred_Microglia', 'scpred_RGC', 'scpred_RPE', 'scpred_Rod', 'scpred_max', 'scpred_prediction', 'seurat_clusters', 'size_factors'
#     uns: 'neighbors', 'umap', 'dataset_colors', 'cell.type_colors'
#     obsm: 'latent', 'X_umap'

# %%
sc.tl.pca(adata)
print('neighbors')
sc.pp.neighbors(adata, use_rep='latent')
print('umap')
sc.tl.umap(adata)

sc.pl.umap(adata, color=['dataset', 'cell.type'])

# %%
import scIB

# %%
sc.pp.filter_genes(adata, min_cells=1)
scIB.pp.reduce_data(adata, n_top_genes=2000, neighbors=True,
                    use_rep='X_pca', pca=True, umap=False)
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/anndata.py:1056: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# HVG
# Calculating 2000 HVGs for reduce_data.
# Computed 999 highly variable genes
# PCA
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/anndata/_core/anndata.py:1056: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# Nearest Neigbours
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../../../home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color=['dataset', 'cell.type'])

# %%
sc.pp.neighbors(adata, use_rep='latent')
sc.tl.umap(adata)
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../../../home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))

# %%
sc.set_figure_params(facecolor='white')

# %%
sc.pl.umap(adata, color=['dataset', 'cell.type'])

# %%
sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)
# Out:
# /home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/numba/typed_passes.py:271: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../../../../../../../../../home/icb/ignacio.ibarra/miniconda3/envs/scIB-python/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))

# %%
sc.pl.umap(adata, color=['dataset', 'cell.type'])

# %%
sc.pl.umap(adata, color=['dataset', 'cell.type'])
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
sc.set_figure_params(facecolor='white')

# %%
print(exists(input_path), input_path)
print(exists(output_path), output_path)
print('')

parent_directory = os.path.abspath(os.path.join(output_path, os.pardir))
print(exists(parent_directory), parent_directory)
if not exists(parent_directory):
    os.makedirs(parent_directory)

if exists(output_path):
    sys.exit()

ad = sc.read_h5ad(input_path)
print(ad.shape)
print(ad.obs['dataset'].value_counts())
adata = ad
batch = 'batch_donor_dataset'
# adata = scIB.integration.runScGen(adata, batch, labels)
if method == 'scvi':
    print('scVI...')
    integrated = scIB.integration.runScvi(adata, batch)
    sc.write(output_path, integrated)

elif method == 'scanvi':
    print('scanvi')
    # scvi
    integrated_scanvi = scIB.integration.runScanvi(adata, batch, cell_type_key)
    print ('about to write to output scANVI...')
    # assert False
    sc.write(output_path, integrated_scanvi)

    print(exists(output_path), output_path)
    print('writing done...')
# Out:
# False /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K/scvi.h5ad
# False /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K/scanvi.h5ad
# False /home/icb/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
#
# False /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.1K
# False /home/icb/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/prepare/unscaled/HVG.1K/adata_pre.h5ad
# input does not exists. Skip...
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.2K/scvi.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.2K/scanvi.h5ad
# True /home/icb/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/prepare/unscaled/HVG.2K/adata_pre.h5ad
#
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.2K
# False /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.3K/scvi.h5ad
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.3K/scanvi.h5ad
# True /home/icb/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/prepare/unscaled/HVG.3K/adata_pre.h5ad
#
# True /storage/groups/ml01/workspace/ignacio.ibarra/theislab/scIB_output/retinal_250_batch_donor_dataset_cell.type/integration/unscaled/HVG.3K
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-9a7401621dba> in <module>
#      26         ad = sc.read_h5ad(p)
#      27
# ---> 28         assert False
#      29
#      30         print(ad.shape)
#
# AssertionError:
